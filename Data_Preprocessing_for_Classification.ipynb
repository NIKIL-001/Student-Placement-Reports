# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import LabelEncoder

import statsmodels.api as sm
from sklearn.model_selection import train_test_split

# %%
PS.at[5033, 'salary_package_lpa'] = 0.00

# %%
PS['salary_package_lpa'].head(10)
PS['salary_package_lpa'].tail(10)

# %%
X1 = PS.drop(['student_id', 'placement_status', 'salary_package_lpa'], axis=1)
X1

# %%
X1= pd.get_dummies(X1, columns=['gender', 'branch', 'college_tier', 'volunteer_experience'], drop_first=True)

# %%
X1 = X1.astype(float)

# %%
print(X1.shape)
print(X1.isnull().sum().sum())

# %%
Y1 = PS[['placement_status']]
Y1

# %%
numeric_features = X1.select_dtypes(exclude = ['object']).columns
numeric_features

# %%
numeric_features1 = X1.select_dtypes(include = ['int64']).columns
numeric_features1

numeric_features2 = X1.select_dtypes(include = ['float64']).columns
numeric_features2

# %%
le = LabelEncoder()

# %%
Y = le.fit_transform(PS['placement_status'])
Y

# %%
X1_train, X1_test, Y_train, Y_test = train_test_split(X1, Y,
                                                      test_size=0.2,
                                                      random_state=42)

print(X1_train.shape)
print(X1_test.shape)
