# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
PS = pd.read_csv(r"/content/student_placement_prediction_dataset (1).csv")

# %%
PS.info()
PS.shape
PS.head()

# %%
plt.scatter(x = PS['cgpa'], y = PS['salary_package_lpa'])

# %%
duplicate = PS.duplicated()
duplicate

# %%
sns.boxplot(x = PS['cgpa'])

# %%
sns.boxplot(x = PS['salary_package_lpa'])

# %%
PS.isnull().sum()
