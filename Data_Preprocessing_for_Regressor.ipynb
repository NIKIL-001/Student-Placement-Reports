# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV

# %%
PS1 = PS[PS['placement_status'] == 'Placed']

X_reg = PS1.drop(['student_id', 'placement_status', 'salary_package_lpa'], axis=1)
Y_reg = PS1['salary_package_lpa']

print(X_reg.shape)
print(Y_reg.shape)

# %%
X_reg = PS1.drop(['student_id', 'placement_status', 'salary_package_lpa'], axis=1)
X_reg

# %%
Y_reg = PS1[['salary_package_lpa']]
Y_reg

# %%
X_reg = pd.get_dummies(X_reg, columns=['gender', 'branch', 'college_tier', 'volunteer_experience'], drop_first=True)

X_reg = X_reg.astype(float)

print(X_reg.dtypes.unique())
print(X_reg.isnull().sum().sum())

# %%
X_train1, X_test1, Y_train1, Y_test1 = train_test_split(X_reg, Y_reg, test_size=0.2, random_state=42)
